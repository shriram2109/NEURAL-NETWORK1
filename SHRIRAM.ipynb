# %%
import numpy as np
import random
import math
import matplotlib.pyplot as plt

# %%
alp = 0.5

# %%
arr = [[0,0],[0,1],[1,0],[1,1]]
inp = np.array(arr)
inp
# Out:
# array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])

# %%
arr1 = [[0,0],[0,0],[0,1],[1,1]] 
out = np.array(arr1)
out
# Out:
# array([[0, 0],
#        [0, 0],
#        [0, 1],
#        [1, 1]])

# %%
perceptrons_weights = []
for i in range(6): 
    perceptrons_weights.append(random.randrange(45,55))
lw1 = perceptrons_weights[:2]
lw2 = perceptrons_weights[2:4]
lw3 = perceptrons_weights[4:6]
wt = np.array([lw1,lw2,lw3]) 
wt
# Out:
# array([[53, 48],
#        [49, 54],
#        [50, 49]])

# %%
def multiply(perceptrons_weights,sigarray):  
    mul = perceptrons_weights*sigarray
    return mul

# %%
def sigmoid(x):
    z = 1/(1 + np.exp(-x))
    return z
vector = np.vectorize(sigmoid) 

for i in range(0,len(inp)):
    layer1 = vector(multiply(wt[0],inp[i])) #Values for layer1 (Input layer)
    layer2 = vector(multiply(wt[1],layer1)) #Values for layer2 (Hidden layer)
    layer3 = vector(multiply(wt[2],layer2)) #Values for layer3 (Output layer)
    
    #Backward Propagation
    
    er3 = (out[i] - layer3)*(np.ones(2) - layer3)*layer3*layer2 
    wt[2] = wt[2] + (alp * er3)
    er2 = (out[i] - layer3)*(np.ones(2) - layer3)* layer3 * wt[2] * (np.ones(2) - layer2) * layer2 * layer1 
    wt[1] = wt[1] + (alp * er2)
    er1 = (out[i] - layer3)*(np.ones(2) - layer3)*layer3*wt[2]*(np.ones(2) - layer2)*layer2*wt[1]*(np.ones(2) - layer1)*layer1*inp[i] 
    wt[0] = wt[0] + (alp * er1) 
print(wt)
# Out:
# [[53 48]
#  [49 54]
#  [50 49]]

# %%
sample = np.array([1,1]) 
sample
# Out:
# array([1, 1])

# %%
layer1 = vector(multiply(wt[0],sample))
layer2 = vector(multiply(wt[1],sample)) 
layer3 = vector(multiply(wt[2],sample))

# %%
layer3
# Out:
# array([1., 1.])

# %%
import tensorflow as tf
from tensorflow import keras

# %%
# Input arrays
a = np.array([0, 0, 1, 1])
b = np.array([0, 1, 0, 1])
# Output array
out = np.array([0, 0, 0, 1])
# Final input array is obtained after combining the input elements into a new array.
total_input = []

for i, j in zip(a, b):
    input1 = []
    input1.append(i)
    input1.append(j)
    total_input.append(input1)
    
total_input = np.array(total_input) #Final input array
total_input
# Out:
# array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])

# %%
x_train = []
y_train = []

for i, j in zip(total_input, out):
    x_train.append(i)
    y_train.append(j)
    
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Sequential

model = keras.Sequential(name="my_sequential")
model.add(Input(shape = x_train[0].shape))
model.add(Dense(10, activation = "relu"))
model.add(Dense(10, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))
model.summary()
# Out:
# Model: "my_sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = "binary_accuracy")

# %%
model.fit(x_train, y_train, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 953ms/step - loss: 0.7231 - binary_accuracy: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7214 - binary_accuracy: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7197 - binary_accuracy: 0.5000
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7181 - binary_accuracy: 0.5000
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7164 - binary_accuracy: 0.5000
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7149 - binary_accuracy: 0.5000
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7133 - binary_accuracy: 0.5000
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7118 - binary_accuracy: 0.5000
# Epoch 9/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7102 - binary_accuracy: 0.5000
# Epoch 10/500
# ...

# %%
model.predict(x_train)
# Out:
# 1/1 [==============================] - 0s 265ms/step
# array([[0.0927017 ],
#        [0.08780257],
#        [0.09008154],
#        [0.9319437 ]], dtype=float32)
